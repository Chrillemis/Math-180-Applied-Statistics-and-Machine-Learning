# %%
import numpy as np

# %%
Hs = np.array([13.2, 27.9, 41.3, 56.6, 68.1])
He = np.array([12, 28, 42, 58, 69])

# %%
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %%
plt.figure(figsize = (6,4))

# def linfunc(x, a, b):
#     return a*x + b

# par = curve_fit(linfunc, Hs, He)
X = np.linspace(np.min(Hs)-10, np.max(Hs)+10,100)
# Y = linfunc(X, *par[0])

plt.plot(X,X, '--', c = "red", label = "$y=x$ line" )
plt.legend()
plt.scatter(Hs,He)
plt.ylabel("$H_{{eye}}$ [cm]")
plt.xlabel("$H_{{sensor}}$ [cm]")
plt.grid()

# %%
data = np.genfromtxt('DataFluid1.csv', delimiter = ';')
# data[0][0] = 23.
plt.figure(figsize = (6,4))
print(data)
plt.plot(data[:,1], data[:,2])
# plt.title("Raw data obtained from Level Logger")
plt.xlabel("Time [s]")
plt.ylabel("$H_{{sensor}}$ [cm]")
plt.grid()
# Out:
# [[       nan 0.0000e+00 1.0169e+03        nan        nan        nan]
#  [2.3100e+01 1.0000e+00 1.0167e+03        nan        nan        nan]
#  [2.3100e+01 2.0000e+00 1.0169e+03        nan        nan        nan]
#  ...
#  [2.2500e+01 4.8700e+02 1.0166e+03        nan        nan        nan]
#  [2.2500e+01 4.8800e+02 1.0166e+03        nan        nan        nan]
#  [2.2500e+01 4.8900e+02 1.0166e+03        nan        nan        nan]]
